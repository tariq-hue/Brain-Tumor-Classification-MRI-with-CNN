# %% [markdown]
# # <center>Thank You!

# %%
# Brain Tumor MRI Classification using a Custom CNN (from scratch)

# =========================
# 1. Import Libraries
# =========================
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import shuffle

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# =========================
# 2. Define Labels & Load Data
# =========================
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

X = []
y = []
image_size =224 #150

Xt = []
yt = []

# Training images
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri','Training',i)
    for j in tqdm(os.listdir(folderPath), desc=f"Loading Training {i}"):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X.append(img)
        y.append(i)



X = np.array(X)
y = np.array(y)

print("Dataset shape:", X.shape, y.shape)


# Testing images
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri','Testing',i)
    for j in tqdm(os.listdir(folderPath), desc=f"Loading Testing {i}"):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        Xt.append(img)
        yt.append(i)
a = np.array(Xt)
b = np.array(yt)

print("Dataset shape:", a.shape, b.shape)
# Out:
# Loading Training glioma_tumor: 100%|██████████| 826/826 [00:03<00:00, 223.77it/s]
# Loading Training no_tumor: 100%|██████████| 395/395 [00:01<00:00, 281.20it/s]
# Loading Training meningioma_tumor: 100%|██████████| 822/822 [00:03<00:00, 240.90it/s]
# Loading Training pituitary_tumor: 100%|██████████| 827/827 [00:03<00:00, 221.79it/s]
# Loading Testing glioma_tumor:  20%|██        | 20/100 [00:00<00:00, 194.48it/s]
# Dataset shape: (2870, 224, 224, 3) (2870,)
# Loading Testing glioma_tumor: 100%|██████████| 100/100 [00:00<00:00, 231.18it/s]
# Loading Testing no_tumor: 100%|██████████| 105/105 [00:00<00:00, 440.17it/s]
# Loading Testing meningioma_tumor: 100%|██████████| 115/115 [00:00<00:00, 265.31it/s]
# Loading Testing pituitary_tumor: 100%|██████████| 74/74 [00:00<00:00, 145.61it/s]
# Dataset shape: (394, 224, 224, 3) (394,)

# %%
# =========================
# 3. Shuffle & Split Data
# =========================
X, y = shuffle(X, y, random_state=82)

# Encode labels into integers
y_encoded = [labels.index(i) for i in y]
y_encoded = tf.keras.utils.to_categorical(y_encoded, num_classes=len(labels))

# # Train/Test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y_encoded, test_size=0.1, random_state=101
# )

# Normalize images
X_train = X/255.0
X_test = a/255.0



print("Train set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Train set: (2870, 224, 224, 3) (2937, 4)
# Test set: (394, 224, 224, 3) (327, 4)

# %%
# =========================
# 4. Build Custom CNN Model
# =========================
model = Sequential([

    # Block 1
    Conv2D(32, (3,3), activation='relu', padding='same',
           input_shape=(image_size,image_size,3)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    # Dropout(0.25),

    # Block 2
    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    # Dropout(0.25),

    # Block 3
    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    # Dropout(0.25),

    # Block 4
    Conv2D(256, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    # Dropout(0.3),
    

    # Block 6
    Conv2D(128, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
    
    # Block 7
    Conv2D(64, (3,3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.25),
   
    # Dense layers
    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    

    

    Dense(len(labels), activation='softmax')
])

model.summary()

# =========================
# 5. Compile Model
# =========================
model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# =========================
# 6. Train Model
# =========================
history = model.fit(
     X, y_encoded,
    validation_split=0.1,
    epochs=50,
    batch_size=8,
    verbose=1
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_48 (Conv2D)           (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 224, 224, 32)      128
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 112, 112, 64)      18496
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 112, 112, 64)      256
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 56, 56, 128)       73856
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 56, 56, 128)       512
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 28, 28, 256)       295168
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 28, 28, 256)       1024
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 14, 14, 128)       295040
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 7, 7, 64)          73792
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 7, 7, 64)          256
# _________________________________________________________________
# max_pooling2d_53 (MaxPooling (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               73856
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 4)                 516
# =================================================================
# Total params: 834,820
# Trainable params: 833,220
# Non-trainable params: 1,600
# _________________________________________________________________
# Epoch 1/50
# 323/323 [==============================] - 22s 64ms/step - loss: 1.3598 - accuracy: 0.5048 - val_loss: 1.6813 - val_accuracy: 0.5226
# Epoch 2/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.9488 - accuracy: 0.6373 - val_loss: 0.7621 - val_accuracy: 0.6794
# Epoch 3/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.8250 - accuracy: 0.6755 - val_loss: 0.8522 - val_accuracy: 0.6237
# Epoch 4/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.8267 - accuracy: 0.6521 - val_loss: 1.1933 - val_accuracy: 0.6167
# Epoch 5/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7492 - accuracy: 0.6962 - val_loss: 2.8512 - val_accuracy: 0.4216
# Epoch 6/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.9390 - accuracy: 0.6126 - val_loss: 1.0160 - val_accuracy: 0.5923
# Epoch 7/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.8203 - accuracy: 0.6708 - val_loss: 0.8442 - val_accuracy: 0.6446
# Epoch 8/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7127 - accuracy: 0.7247 - val_loss: 0.9543 - val_accuracy: 0.5993
# Epoch 9/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.6089 - accuracy: 0.7670 - val_loss: 2.3634 - val_accuracy: 0.4286
# Epoch 10/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.9000 - accuracy: 0.6308 - val_loss: 2.5943 - val_accuracy: 0.4495
# Epoch 11/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.8312 - accuracy: 0.6589 - val_loss: 0.7144 - val_accuracy: 0.7038
# Epoch 12/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7440 - accuracy: 0.6983 - val_loss: 1.8710 - val_accuracy: 0.3693
# Epoch 13/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.9090 - accuracy: 0.6275 - val_loss: 0.7587 - val_accuracy: 0.6585
# Epoch 14/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7375 - accuracy: 0.7076 - val_loss: 0.8489 - val_accuracy: 0.6098
# Epoch 15/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.9187 - accuracy: 0.6083 - val_loss: 1.4212 - val_accuracy: 0.4111
# Epoch 16/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.8794 - accuracy: 0.6310 - val_loss: 0.7076 - val_accuracy: 0.6725
# Epoch 17/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7561 - accuracy: 0.7029 - val_loss: 0.5489 - val_accuracy: 0.7875
# Epoch 18/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.7059 - accuracy: 0.7383 - val_loss: 0.5542 - val_accuracy: 0.7700
# Epoch 19/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.6430 - accuracy: 0.7458 - val_loss: 3.7295 - val_accuracy: 0.6760
# Epoch 20/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.6939 - accuracy: 0.7160 - val_loss: 0.5663 - val_accuracy: 0.7909
# Epoch 21/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.5796 - accuracy: 0.7810 - val_loss: 0.5012 - val_accuracy: 0.8397
# Epoch 22/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.5124 - accuracy: 0.8137 - val_loss: 0.9888 - val_accuracy: 0.7213
# Epoch 23/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.5061 - accuracy: 0.8089 - val_loss: 0.9405 - val_accuracy: 0.6446
# Epoch 24/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.5513 - accuracy: 0.8022 - val_loss: 0.6062 - val_accuracy: 0.7666
# Epoch 25/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.5627 - accuracy: 0.7819 - val_loss: 0.5087 - val_accuracy: 0.8258
# Epoch 26/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.5259 - accuracy: 0.8118 - val_loss: 0.5754 - val_accuracy: 0.7909
# Epoch 27/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.4805 - accuracy: 0.8169 - val_loss: 0.3806 - val_accuracy: 0.8502
# Epoch 28/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.4613 - accuracy: 0.8260 - val_loss: 0.4465 - val_accuracy: 0.7944
# Epoch 29/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.4753 - accuracy: 0.8234 - val_loss: 0.7211 - val_accuracy: 0.7875
# Epoch 30/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.4740 - accuracy: 0.8336 - val_loss: 0.2791 - val_accuracy: 0.9094
# Epoch 31/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.4555 - accuracy: 0.8404 - val_loss: 0.2319 - val_accuracy: 0.9164
# Epoch 32/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.3651 - accuracy: 0.8764 - val_loss: 0.2985 - val_accuracy: 0.8885
# Epoch 33/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.3346 - accuracy: 0.8864 - val_loss: 0.2238 - val_accuracy: 0.9268
# Epoch 34/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3294 - accuracy: 0.8854 - val_loss: 0.2551 - val_accuracy: 0.9129
# Epoch 35/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3384 - accuracy: 0.8731 - val_loss: 0.5744 - val_accuracy: 0.7805
# Epoch 36/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3678 - accuracy: 0.8787 - val_loss: 0.3697 - val_accuracy: 0.8676
# Epoch 37/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3833 - accuracy: 0.8724 - val_loss: 0.3207 - val_accuracy: 0.9024
# Epoch 38/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3660 - accuracy: 0.8760 - val_loss: 0.2808 - val_accuracy: 0.9094
# Epoch 39/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3159 - accuracy: 0.8965 - val_loss: 0.2652 - val_accuracy: 0.9199
# Epoch 40/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.3106 - accuracy: 0.8945 - val_loss: 0.2643 - val_accuracy: 0.9059
# Epoch 41/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2498 - accuracy: 0.9205 - val_loss: 0.2009 - val_accuracy: 0.9373
# Epoch 42/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2203 - accuracy: 0.9202 - val_loss: 0.3496 - val_accuracy: 0.8920
# Epoch 43/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2387 - accuracy: 0.9229 - val_loss: 0.2903 - val_accuracy: 0.9512
# Epoch 44/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2246 - accuracy: 0.9265 - val_loss: 0.1520 - val_accuracy: 0.9443
# Epoch 45/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2957 - accuracy: 0.9072 - val_loss: 0.4698 - val_accuracy: 0.8153
# Epoch 46/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2227 - accuracy: 0.9261 - val_loss: 2.5680 - val_accuracy: 0.8258
# Epoch 47/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2230 - accuracy: 0.9291 - val_loss: 0.1767 - val_accuracy: 0.9512
# Epoch 48/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2617 - accuracy: 0.9136 - val_loss: 0.3454 - val_accuracy: 0.8990
# Epoch 49/50
# 323/323 [==============================] - 20s 63ms/step - loss: 0.2439 - accuracy: 0.9118 - val_loss: 0.1311 - val_accuracy: 0.9756
# Epoch 50/50
# 323/323 [==============================] - 21s 64ms/step - loss: 0.1831 - accuracy: 0.9426 - val_loss: 0.1388 - val_accuracy: 0.9547
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ebcebb656ed3> in <module>
#     102 # 8. Evaluation
#     103 # =========================
# --> 104 test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
#     105 print("Test Accuracy:", test_acc)
#     106
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1364             use_multiprocessing=use_multiprocessing,
#    1365             model=self,
# -> 1366             steps_per_execution=self._steps_per_execution)
#    1367
#    1368       # Container that configures and calls `tf.keras.Callback`s.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     272
#     273     num_samples = set(int(i.shape[0]) for i in nest.flatten(inputs)).pop()
# --> 274     _check_data_cardinality(inputs)
#     275
#     276     # If batch_size is not passed but steps is, calculate from the input data.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in _check_data_cardinality(data)
#    1527           label, ", ".join(str(i.shape[0]) for i in nest.flatten(single_data)))
#    1528     msg += "Make sure all arrays contain the same number of samples."
# -> 1529     raise ValueError(msg)
#    1530
#    1531
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 394
#   y sizes: 327
# Make sure all arrays contain the same number of samples.

# %%
# Train/Test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.1, random_state=101
)


# =========================
# 7. Training Curves
# =========================
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")

plt.show()

# =========================
# 8. Evaluation
# =========================
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)
print("Test Accuracy:", test_acc)

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print("Classification Report:")
print(classification_report(y_true, y_pred_classes, target_names=labels))

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=labels,
            yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 9/9 [==============================] - 3s 344ms/step - loss: 0.0271 - accuracy: 0.9895
# Test Accuracy: 0.9895470142364502
# Classification Report:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.92      0.96        72
#         no_tumor       0.75      0.95      0.84        38
# meningioma_tumor       0.98      0.96      0.97        84
#  pituitary_tumor       1.00      0.97      0.98        93
#
#         accuracy                           0.95       287
#        macro avg       0.93      0.95      0.94       287
#     weighted avg       0.96      0.95      0.95       287
